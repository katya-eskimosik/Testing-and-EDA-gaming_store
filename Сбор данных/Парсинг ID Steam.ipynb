# %% [markdown]
# ID игр

# %%
import requests
from bs4 import BeautifulSoup
import time
import csv
import random

class SteamGameParser:
    def __init__(self):
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        }
        self.session = requests.Session()
        self.session.headers.update(self.headers)
        self.game_ids = set()

    def extract_game_ids(self, html):
        soup = BeautifulSoup(html, 'html.parser')
        return {href.split('/app/')[1].split('/')[0]
                for link in soup.find_all('a', href=True)
                if '/app/' in (href := link['href']) and href.split('/app/')[1].split('/')[0].isdigit()}

    def get_game_ids_from_url(self, url, delay=True):
        try:
            response = self.session.get(url, timeout=15)
            ids = self.extract_game_ids(response.content)
            if delay:
                time.sleep(random.uniform(1, 2))
            return ids
        except Exception as e:
            print(f"Ошибка при парсинге {url}: {e}")
            return set()

    def get_game_ids_from_search(self, start=0, count=100, sort_by='_ASC'):
        params = {
            'start': start,
            'count': count,
            'dynamic_data': '',
            'sort_by': sort_by,
            'infinite': 1
        }

        try:
            response = self.session.get("https://store.steampowered.com/search/results/", params=params, timeout=15)
            if response.status_code == 200:
                return self.extract_game_ids(response.json().get('results_html', ''))
        except Exception as e:
            print(f"Ошибка при парсинге страницы {start}: {e}")
        return set()

    def collect_ids_from_sources(self):
        #категории
        featured_urls = [
            "https://store.steampowered.com/search/?sort_by=Released_DESC&category1=998",
            "https://store.steampowered.com/search/?filter=topsellers&category1=998",
            "https://store.steampowered.com/search/?sort_by=Price_ASC&category1=998",
            "https://store.steampowered.com/search/?sort_by=Metacritic&category1=998",
            "https://store.steampowered.com/search/?category1=998&specials=1",
        ]

        # Популярные теги
        tags = ["action", "adventure", "rpg", "strategy", "simulation", "indie", "horror"]

        all_ids = set()
        for url in featured_urls:
            all_ids.update(self.get_game_ids_from_url(url))

        for tag in tags:
            all_ids.update(self.get_game_ids_from_url(f"https://store.steampowered.com/search/?tags={tag}"))

        return all_ids

    def parse_with_different_sorts(self, total_games=25000):
        sort_methods = ['_ASC', 'Released_DESC', 'Price_ASC', 'Price_DESC', 'Reviews_DESC']

        for sort_method in sort_methods:
            if len(self.game_ids) >= total_games:
                break

            print(f"Парсинг с сортировкой: {sort_method}")
            for page in range(200):
                if len(self.game_ids) >= total_games:
                    break

                new_ids = self.get_game_ids_from_search(page*100, 100, sort_method)
                before = len(self.game_ids)
                self.game_ids.update(new_ids)

                if len(self.game_ids) - before < 5:
                    break

                time.sleep(random.uniform(1, 2))

    def parse_games(self, total_games=25000):
        print("Начинаем парсинг Steam...")

        initial_ids = self.collect_ids_from_sources()
        self.game_ids.update(initial_ids)
        print(f"Собрано начальных ID: {len(initial_ids)}")

        self.parse_with_different_sorts(total_games)

        print(f"Итоговый результат: {len(self.game_ids)} уникальных ID игр")

    def save_to_csv(self, filename='steam_game_ids.csv'):
        with open(filename, 'w', newline='', encoding='utf-8') as file:
            csv.writer(file).writerows([['Game ID'], *[[game_id] for game_id in self.game_ids]])


parser = SteamGameParser()
try:
    parser.parse_games(total_games=25000)
    parser.save_to_csv()
except Exception as e:
    print(f"Ошибка: {e}")
    parser.save_to_csv('steam_game_ids_fail.csv')
# Out:
# Начинаем парсинг Steam для сбора 25000 игр...
# 1. Сбор из featured категорий...
# Обработана категория: https://store.steampowered.com/search/?sort_by=Released_DESC&category1=998, найдено: 50
# Обработана категория: https://store.steampowered.com/search/?filter=topsellers&category1=998, найдено: 100
# Обработана категория: https://store.steampowered.com/search/?sort_by=Price_ASC&category1=998, найдено: 136
# Обработана категория: https://store.steampowered.com/search/?sort_by=Metacritic&category1=998, найдено: 143
# Обработана категория: https://store.steampowered.com/search/?category1=998&specials=1, найдено: 179
# Обработана категория: https://store.steampowered.com/search/?category1=998&os=win&filter=popularnew, найдено: 179
# Обработана категория: https://store.steampowered.com/search/?category1=998&os=win&filter=comingsoon, найдено: 229
# Найдено из featured: 229
# 2. Сбор по тегам...
# Обработан тег: action, найдено игр: 50
# Обработан тег: adventure, найдено игр: 50
# Обработан тег: rpg, найдено игр: 50
# Обработан тег: strategy, найдено игр: 50
# Обработан тег: simulation, найдено игр: 50
# Обработан тег: casual, найдено игр: 50
# Обработан тег: sports, найдено игр: 50
# Обработан тег: racing, найдено игр: 50
# Обработан тег: indie, найдено игр: 50
# Обработан тег: horror, найдено игр: 50
# Обработан тег: puzzle, найдено игр: 50
# Обработан тег: platformer, найдено игр: 50
# Обработан тег: shooter, найдено игр: 50
# Обработан тег: fighting, найдено игр: 50
# Обработан тег: arcade, найдено игр: 50
# Обработан тег: open-world, найдено игр: 50
# Обработан тег: story-rich, найдено игр: 50
# Обработан тег: singleplayer, найдено игр: 50
# Обработан тег: multiplayer, найдено игр: 50
# Обработан тег: co-op, найдено игр: 50
# Обработан тег: fps, найдено игр: 50
# Обработан тег: tps, найдено игр: 50
# Обработан тег: roguelike, найдено игр: 50
# Обработан тег: survival, найдено игр: 50
# Обработан тег: crafting, найдено игр: 50
# Обработан тег: 2d, найдено игр: 50
# Обработан тег: 3d, найдено игр: 50
# Обработан тег: vr, найдено игр: 50
# Обработан тег: anime, найдено игр: 50
# Обработан тег: fantasy, найдено игр: 50
# Обработан тег: sci-fi, найдено игр: 50
# Обработан тег: comedy, найдено игр: 50
# Обработан тег: mystery, найдено игр: 50
# Обработан тег: thriller, найдено игр: 50
# Обработан тег: romance, найдено игр: 50
# Найдено по тегам: 50
# 3. Сбор из кураторов...
# Найдено из кураторов: 0
# Всего собрано после начального этапа: 230
# 4. Массовый сбор через поиск с разными сортировками...
# Парсинг с сортировкой: _ASC
# Парсинг страницы 1, смещение: 0, сортировка: _ASC
# Добавлено новых ID: 27, всего: 257
# Парсинг страницы 2, смещение: 100, сортировка: _ASC
# Добавлено новых ID: 77, всего: 334
# Парсинг страницы 3, смещение: 200, сортировка: _ASC
# Добавлено новых ID: 78, всего: 412
# Парсинг страницы 4, смещение: 300, сортировка: _ASC
# Добавлено новых ID: 93, всего: 505
# Парсинг страницы 5, смещение: 400, сортировка: _ASC
# Добавлено новых ID: 98, всего: 603
# Парсинг страницы 6, смещение: 500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 703
# Парсинг страницы 7, смещение: 600, сортировка: _ASC
# Добавлено новых ID: 98, всего: 801
# Парсинг страницы 8, смещение: 700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 901
# Парсинг страницы 9, смещение: 800, сортировка: _ASC
# Добавлено новых ID: 99, всего: 1000
# Парсинг страницы 10, смещение: 900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 1100
# Парсинг страницы 11, смещение: 1000, сортировка: _ASC
# Добавлено новых ID: 99, всего: 1199
# Парсинг страницы 12, смещение: 1100, сортировка: _ASC
# Добавлено новых ID: 99, всего: 1298
# Парсинг страницы 13, смещение: 1200, сортировка: _ASC
# Добавлено новых ID: 99, всего: 1397
# Парсинг страницы 14, смещение: 1300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 1497
# Парсинг страницы 15, смещение: 1400, сортировка: _ASC
# Добавлено новых ID: 99, всего: 1596
# Парсинг страницы 16, смещение: 1500, сортировка: _ASC
# Добавлено новых ID: 99, всего: 1695
# Парсинг страницы 17, смещение: 1600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 1795
# Парсинг страницы 18, смещение: 1700, сортировка: _ASC
# Добавлено новых ID: 99, всего: 1894
# Парсинг страницы 19, смещение: 1800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 1994
# Парсинг страницы 20, смещение: 1900, сортировка: _ASC
# Добавлено новых ID: 99, всего: 2093
# Парсинг страницы 21, смещение: 2000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 2193
# Парсинг страницы 22, смещение: 2100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 2293
# Парсинг страницы 23, смещение: 2200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 2393
# Парсинг страницы 24, смещение: 2300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 2493
# Парсинг страницы 25, смещение: 2400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 2593
# Парсинг страницы 26, смещение: 2500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 2693
# Парсинг страницы 27, смещение: 2600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 2793
# Парсинг страницы 28, смещение: 2700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 2893
# Парсинг страницы 29, смещение: 2800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 2993
# Парсинг страницы 30, смещение: 2900, сортировка: _ASC
# Добавлено новых ID: 99, всего: 3092
# Парсинг страницы 31, смещение: 3000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 3192
# Парсинг страницы 32, смещение: 3100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 3292
# Парсинг страницы 33, смещение: 3200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 3392
# Парсинг страницы 34, смещение: 3300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 3492
# Парсинг страницы 35, смещение: 3400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 3592
# Парсинг страницы 36, смещение: 3500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 3692
# Парсинг страницы 37, смещение: 3600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 3792
# Парсинг страницы 38, смещение: 3700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 3892
# Парсинг страницы 39, смещение: 3800, сортировка: _ASC
# Добавлено новых ID: 99, всего: 3991
# Парсинг страницы 40, смещение: 3900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 4091
# Парсинг страницы 41, смещение: 4000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 4191
# Парсинг страницы 42, смещение: 4100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 4291
# Парсинг страницы 43, смещение: 4200, сортировка: _ASC
# Добавлено новых ID: 99, всего: 4390
# Парсинг страницы 44, смещение: 4300, сортировка: _ASC
# Добавлено новых ID: 99, всего: 4489
# Парсинг страницы 45, смещение: 4400, сортировка: _ASC
# Добавлено новых ID: 99, всего: 4588
# Парсинг страницы 46, смещение: 4500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 4688
# Парсинг страницы 47, смещение: 4600, сортировка: _ASC
# Добавлено новых ID: 98, всего: 4786
# Парсинг страницы 48, смещение: 4700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 4886
# Парсинг страницы 49, смещение: 4800, сортировка: _ASC
# Добавлено новых ID: 99, всего: 4985
# Парсинг страницы 50, смещение: 4900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 5085
# Парсинг страницы 51, смещение: 5000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 5185
# Парсинг страницы 52, смещение: 5100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 5285
# Парсинг страницы 53, смещение: 5200, сортировка: _ASC
# Добавлено новых ID: 99, всего: 5384
# Парсинг страницы 54, смещение: 5300, сортировка: _ASC
# Добавлено новых ID: 99, всего: 5483
# Парсинг страницы 55, смещение: 5400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 5583
# Парсинг страницы 56, смещение: 5500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 5683
# Парсинг страницы 57, смещение: 5600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 5783
# Парсинг страницы 58, смещение: 5700, сортировка: _ASC
# Добавлено новых ID: 99, всего: 5882
# Парсинг страницы 59, смещение: 5800, сортировка: _ASC
# Добавлено новых ID: 99, всего: 5981
# Парсинг страницы 60, смещение: 5900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 6081
# Парсинг страницы 61, смещение: 6000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 6181
# Парсинг страницы 62, смещение: 6100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 6281
# Парсинг страницы 63, смещение: 6200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 6381
# Парсинг страницы 64, смещение: 6300, сортировка: _ASC
# Добавлено новых ID: 99, всего: 6480
# Парсинг страницы 65, смещение: 6400, сортировка: _ASC
# Добавлено новых ID: 98, всего: 6578
# Парсинг страницы 66, смещение: 6500, сортировка: _ASC
# Добавлено новых ID: 99, всего: 6677
# Парсинг страницы 67, смещение: 6600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 6777
# Парсинг страницы 68, смещение: 6700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 6877
# Парсинг страницы 69, смещение: 6800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 6977
# Парсинг страницы 70, смещение: 6900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 7077
# Парсинг страницы 71, смещение: 7000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 7177
# Парсинг страницы 72, смещение: 7100, сортировка: _ASC
# Добавлено новых ID: 99, всего: 7276
# Парсинг страницы 73, смещение: 7200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 7376
# Парсинг страницы 74, смещение: 7300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 7476
# Парсинг страницы 75, смещение: 7400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 7576
# Парсинг страницы 76, смещение: 7500, сортировка: _ASC
# Добавлено новых ID: 98, всего: 7674
# Парсинг страницы 77, смещение: 7600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 7774
# Парсинг страницы 78, смещение: 7700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 7874
# Парсинг страницы 79, смещение: 7800, сортировка: _ASC
# Добавлено новых ID: 98, всего: 7972
# Парсинг страницы 80, смещение: 7900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 8072
# Парсинг страницы 81, смещение: 8000, сортировка: _ASC
# Добавлено новых ID: 99, всего: 8171
# Парсинг страницы 82, смещение: 8100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 8271
# Парсинг страницы 83, смещение: 8200, сортировка: _ASC
# Добавлено новых ID: 98, всего: 8369
# Парсинг страницы 84, смещение: 8300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 8469
# Парсинг страницы 85, смещение: 8400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 8569
# Парсинг страницы 86, смещение: 8500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 8669
# Парсинг страницы 87, смещение: 8600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 8769
# Парсинг страницы 88, смещение: 8700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 8869
# Парсинг страницы 89, смещение: 8800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 8969
# Парсинг страницы 90, смещение: 8900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 9069
# Парсинг страницы 91, смещение: 9000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 9169
# Парсинг страницы 92, смещение: 9100, сортировка: _ASC
# Добавлено новых ID: 99, всего: 9268
# Парсинг страницы 93, смещение: 9200, сортировка: _ASC
# Добавлено новых ID: 98, всего: 9366
# Парсинг страницы 94, смещение: 9300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 9466
# Парсинг страницы 95, смещение: 9400, сортировка: _ASC
# Добавлено новых ID: 93, всего: 9559
# Парсинг страницы 96, смещение: 9500, сортировка: _ASC
# Добавлено новых ID: 99, всего: 9658
# Парсинг страницы 97, смещение: 9600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 9758
# Парсинг страницы 98, смещение: 9700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 9858
# Парсинг страницы 99, смещение: 9800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 9958
# Парсинг страницы 100, смещение: 9900, сортировка: _ASC
# Добавлено новых ID: 97, всего: 10055
# Парсинг страницы 101, смещение: 10000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 10155
# Парсинг страницы 102, смещение: 10100, сортировка: _ASC
# Добавлено новых ID: 97, всего: 10252
# Парсинг страницы 103, смещение: 10200, сортировка: _ASC
# Добавлено новых ID: 98, всего: 10350
# Парсинг страницы 104, смещение: 10300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 10450
# Парсинг страницы 105, смещение: 10400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 10550
# Парсинг страницы 106, смещение: 10500, сортировка: _ASC
# Добавлено новых ID: 98, всего: 10648
# Парсинг страницы 107, смещение: 10600, сортировка: _ASC
# Добавлено новых ID: 92, всего: 10740
# Парсинг страницы 108, смещение: 10700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 10840
# Парсинг страницы 109, смещение: 10800, сортировка: _ASC
# Добавлено новых ID: 98, всего: 10938
# Парсинг страницы 110, смещение: 10900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 11038
# Парсинг страницы 111, смещение: 11000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 11138
# Парсинг страницы 112, смещение: 11100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 11238
# Парсинг страницы 113, смещение: 11200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 11338
# Парсинг страницы 114, смещение: 11300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 11438
# Парсинг страницы 115, смещение: 11400, сортировка: _ASC
# Добавлено новых ID: 99, всего: 11537
# Парсинг страницы 116, смещение: 11500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 11637
# Парсинг страницы 117, смещение: 11600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 11737
# Парсинг страницы 118, смещение: 11700, сортировка: _ASC
# Добавлено новых ID: 99, всего: 11836
# Парсинг страницы 119, смещение: 11800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 11936
# Парсинг страницы 120, смещение: 11900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 12036
# Парсинг страницы 121, смещение: 12000, сортировка: _ASC
# Добавлено новых ID: 99, всего: 12135
# Парсинг страницы 122, смещение: 12100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 12235
# Парсинг страницы 123, смещение: 12200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 12335
# Парсинг страницы 124, смещение: 12300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 12435
# Парсинг страницы 125, смещение: 12400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 12535
# Парсинг страницы 126, смещение: 12500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 12635
# Парсинг страницы 127, смещение: 12600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 12735
# Парсинг страницы 128, смещение: 12700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 12835
# Парсинг страницы 129, смещение: 12800, сортировка: _ASC
# Добавлено новых ID: 99, всего: 12934
# Парсинг страницы 130, смещение: 12900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 13034
# Парсинг страницы 131, смещение: 13000, сортировка: _ASC
# Добавлено новых ID: 99, всего: 13133
# Парсинг страницы 132, смещение: 13100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 13233
# Парсинг страницы 133, смещение: 13200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 13333
# Парсинг страницы 134, смещение: 13300, сортировка: _ASC
# Добавлено новых ID: 99, всего: 13432
# Парсинг страницы 135, смещение: 13400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 13532
# Парсинг страницы 136, смещение: 13500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 13632
# Парсинг страницы 137, смещение: 13600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 13732
# Парсинг страницы 138, смещение: 13700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 13832
# Парсинг страницы 139, смещение: 13800, сортировка: _ASC
# Добавлено новых ID: 99, всего: 13931
# Парсинг страницы 140, смещение: 13900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 14031
# Парсинг страницы 141, смещение: 14000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 14131
# Парсинг страницы 142, смещение: 14100, сортировка: _ASC
# Добавлено новых ID: 99, всего: 14230
# Парсинг страницы 143, смещение: 14200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 14330
# Парсинг страницы 144, смещение: 14300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 14430
# Парсинг страницы 145, смещение: 14400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 14530
# Парсинг страницы 146, смещение: 14500, сортировка: _ASC
# Добавлено новых ID: 99, всего: 14629
# Парсинг страницы 147, смещение: 14600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 14729
# Парсинг страницы 148, смещение: 14700, сортировка: _ASC
# Добавлено новых ID: 94, всего: 14823
# Парсинг страницы 149, смещение: 14800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 14923
# Парсинг страницы 150, смещение: 14900, сортировка: _ASC
# Добавлено новых ID: 99, всего: 15022
# Парсинг страницы 151, смещение: 15000, сортировка: _ASC
# Добавлено новых ID: 99, всего: 15121
# Парсинг страницы 152, смещение: 15100, сортировка: _ASC
# Добавлено новых ID: 93, всего: 15214
# Парсинг страницы 153, смещение: 15200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 15314
# Парсинг страницы 154, смещение: 15300, сортировка: _ASC
# Добавлено новых ID: 97, всего: 15411
# Парсинг страницы 155, смещение: 15400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 15511
# Парсинг страницы 156, смещение: 15500, сортировка: _ASC
# Добавлено новых ID: 99, всего: 15610
# Парсинг страницы 157, смещение: 15600, сортировка: _ASC
# Добавлено новых ID: 97, всего: 15707
# Парсинг страницы 158, смещение: 15700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 15807
# Парсинг страницы 159, смещение: 15800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 15907
# Парсинг страницы 160, смещение: 15900, сортировка: _ASC
# Добавлено новых ID: 97, всего: 16004
# Парсинг страницы 161, смещение: 16000, сортировка: _ASC
# Добавлено новых ID: 99, всего: 16103
# Парсинг страницы 162, смещение: 16100, сортировка: _ASC
# Добавлено новых ID: 99, всего: 16202
# Парсинг страницы 163, смещение: 16200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 16302
# Парсинг страницы 164, смещение: 16300, сортировка: _ASC
# Добавлено новых ID: 97, всего: 16399
# Парсинг страницы 165, смещение: 16400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 16499
# Парсинг страницы 166, смещение: 16500, сортировка: _ASC
# Добавлено новых ID: 99, всего: 16598
# Парсинг страницы 167, смещение: 16600, сортировка: _ASC
# Добавлено новых ID: 97, всего: 16695
# Парсинг страницы 168, смещение: 16700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 16795
# Парсинг страницы 169, смещение: 16800, сортировка: _ASC
# Добавлено новых ID: 99, всего: 16894
# Парсинг страницы 170, смещение: 16900, сортировка: _ASC
# Добавлено новых ID: 95, всего: 16989
# Парсинг страницы 171, смещение: 17000, сортировка: _ASC
# Добавлено новых ID: 99, всего: 17088
# Парсинг страницы 172, смещение: 17100, сортировка: _ASC
# Добавлено новых ID: 99, всего: 17187
# Парсинг страницы 173, смещение: 17200, сортировка: _ASC
# Добавлено новых ID: 100, всего: 17287
# Парсинг страницы 174, смещение: 17300, сортировка: _ASC
# Добавлено новых ID: 96, всего: 17383
# Парсинг страницы 175, смещение: 17400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 17483
# Парсинг страницы 176, смещение: 17500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 17583
# Парсинг страницы 177, смещение: 17600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 17683
# Парсинг страницы 178, смещение: 17700, сортировка: _ASC
# Добавлено новых ID: 99, всего: 17782
# Парсинг страницы 179, смещение: 17800, сортировка: _ASC
# Добавлено новых ID: 98, всего: 17880
# Парсинг страницы 180, смещение: 17900, сортировка: _ASC
# Добавлено новых ID: 99, всего: 17979
# Парсинг страницы 181, смещение: 18000, сортировка: _ASC
# Добавлено новых ID: 99, всего: 18078
# Парсинг страницы 182, смещение: 18100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 18178
# Парсинг страницы 183, смещение: 18200, сортировка: _ASC
# Добавлено новых ID: 99, всего: 18277
# Парсинг страницы 184, смещение: 18300, сортировка: _ASC
# Добавлено новых ID: 96, всего: 18373
# Парсинг страницы 185, смещение: 18400, сортировка: _ASC
# Добавлено новых ID: 97, всего: 18470
# Парсинг страницы 186, смещение: 18500, сортировка: _ASC
# Добавлено новых ID: 98, всего: 18568
# Парсинг страницы 187, смещение: 18600, сортировка: _ASC
# Добавлено новых ID: 99, всего: 18667
# Парсинг страницы 188, смещение: 18700, сортировка: _ASC
# Добавлено новых ID: 98, всего: 18765
# Парсинг страницы 189, смещение: 18800, сортировка: _ASC
# Добавлено новых ID: 97, всего: 18862
# Парсинг страницы 190, смещение: 18900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 18962
# Парсинг страницы 191, смещение: 19000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 19062
# Парсинг страницы 192, смещение: 19100, сортировка: _ASC
# Добавлено новых ID: 100, всего: 19162
# Парсинг страницы 193, смещение: 19200, сортировка: _ASC
# Добавлено новых ID: 98, всего: 19260
# Парсинг страницы 194, смещение: 19300, сортировка: _ASC
# Добавлено новых ID: 99, всего: 19359
# Парсинг страницы 195, смещение: 19400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 19459
# Парсинг страницы 196, смещение: 19500, сортировка: _ASC
# Добавлено новых ID: 96, всего: 19555
# Парсинг страницы 197, смещение: 19600, сортировка: _ASC
# Добавлено новых ID: 99, всего: 19654
# Парсинг страницы 198, смещение: 19700, сортировка: _ASC
# Добавлено новых ID: 98, всего: 19752
# Парсинг страницы 199, смещение: 19800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 19852
# Парсинг страницы 200, смещение: 19900, сортировка: _ASC
# Добавлено новых ID: 99, всего: 19951
# Парсинг страницы 201, смещение: 20000, сортировка: _ASC
# Добавлено новых ID: 98, всего: 20049
# Парсинг страницы 202, смещение: 20100, сортировка: _ASC
# Добавлено новых ID: 99, всего: 20148
# Парсинг страницы 203, смещение: 20200, сортировка: _ASC
# Добавлено новых ID: 98, всего: 20246
# Парсинг страницы 204, смещение: 20300, сортировка: _ASC
# Добавлено новых ID: 97, всего: 20343
# Парсинг страницы 205, смещение: 20400, сортировка: _ASC
# Добавлено новых ID: 98, всего: 20441
# Парсинг страницы 206, смещение: 20500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 20541
# Парсинг страницы 207, смещение: 20600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 20641
# Парсинг страницы 208, смещение: 20700, сортировка: _ASC
# Добавлено новых ID: 98, всего: 20739
# Парсинг страницы 209, смещение: 20800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 20839
# Парсинг страницы 210, смещение: 20900, сортировка: _ASC
# Добавлено новых ID: 99, всего: 20938
# Парсинг страницы 211, смещение: 21000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 21038
# Парсинг страницы 212, смещение: 21100, сортировка: _ASC
# Добавлено новых ID: 99, всего: 21137
# Парсинг страницы 213, смещение: 21200, сортировка: _ASC
# Добавлено новых ID: 99, всего: 21236
# Парсинг страницы 214, смещение: 21300, сортировка: _ASC
# Добавлено новых ID: 100, всего: 21336
# Парсинг страницы 215, смещение: 21400, сортировка: _ASC
# Добавлено новых ID: 98, всего: 21434
# Парсинг страницы 216, смещение: 21500, сортировка: _ASC
# Добавлено новых ID: 98, всего: 21532
# Парсинг страницы 217, смещение: 21600, сортировка: _ASC
# Добавлено новых ID: 100, всего: 21632
# Парсинг страницы 218, смещение: 21700, сортировка: _ASC
# Добавлено новых ID: 98, всего: 21730
# Парсинг страницы 219, смещение: 21800, сортировка: _ASC
# Добавлено новых ID: 99, всего: 21829
# Парсинг страницы 220, смещение: 21900, сортировка: _ASC
# Добавлено новых ID: 100, всего: 21929
# Парсинг страницы 221, смещение: 22000, сортировка: _ASC
# Добавлено новых ID: 99, всего: 22028
# Парсинг страницы 222, смещение: 22100, сортировка: _ASC
# Добавлено новых ID: 98, всего: 22126
# Парсинг страницы 223, смещение: 22200, сортировка: _ASC
# Добавлено новых ID: 98, всего: 22224
# Парсинг страницы 224, смещение: 22300, сортировка: _ASC
# Добавлено новых ID: 99, всего: 22323
# Парсинг страницы 225, смещение: 22400, сортировка: _ASC
# Добавлено новых ID: 99, всего: 22422
# Парсинг страницы 226, смещение: 22500, сортировка: _ASC
# Добавлено новых ID: 100, всего: 22522
# Парсинг страницы 227, смещение: 22600, сортировка: _ASC
# Добавлено новых ID: 93, всего: 22615
# Парсинг страницы 228, смещение: 22700, сортировка: _ASC
# Добавлено новых ID: 100, всего: 22715
# Парсинг страницы 229, смещение: 22800, сортировка: _ASC
# Добавлено новых ID: 99, всего: 22814
# Парсинг страницы 230, смещение: 22900, сортировка: _ASC
# Добавлено новых ID: 97, всего: 22911
# Парсинг страницы 231, смещение: 23000, сортировка: _ASC
# Добавлено новых ID: 98, всего: 23009
# Парсинг страницы 232, смещение: 23100, сортировка: _ASC
# Добавлено новых ID: 99, всего: 23108
# Парсинг страницы 233, смещение: 23200, сортировка: _ASC
# Добавлено новых ID: 99, всего: 23207
# Парсинг страницы 234, смещение: 23300, сортировка: _ASC
# Добавлено новых ID: 99, всего: 23306
# Парсинг страницы 235, смещение: 23400, сортировка: _ASC
# Добавлено новых ID: 98, всего: 23404
# Парсинг страницы 236, смещение: 23500, сортировка: _ASC
# Добавлено новых ID: 96, всего: 23500
# Парсинг страницы 237, смещение: 23600, сортировка: _ASC
# Добавлено новых ID: 99, всего: 23599
# Парсинг страницы 238, смещение: 23700, сортировка: _ASC
# Добавлено новых ID: 98, всего: 23697
# Парсинг страницы 239, смещение: 23800, сортировка: _ASC
# Добавлено новых ID: 99, всего: 23796
# Парсинг страницы 240, смещение: 23900, сортировка: _ASC
# Добавлено новых ID: 99, всего: 23895
# Парсинг страницы 241, смещение: 24000, сортировка: _ASC
# Добавлено новых ID: 100, всего: 23995
# Парсинг страницы 242, смещение: 24100, сортировка: _ASC
# Добавлено новых ID: 97, всего: 24092
# Парсинг страницы 243, смещение: 24200, сортировка: _ASC
# Добавлено новых ID: 97, всего: 24189
# Парсинг страницы 244, смещение: 24300, сортировка: _ASC
# Добавлено новых ID: 98, всего: 24287
# Парсинг страницы 245, смещение: 24400, сортировка: _ASC
# Добавлено новых ID: 100, всего: 24387
# Парсинг страницы 246, смещение: 24500, сортировка: _ASC
# Добавлено новых ID: 99, всего: 24486
# Парсинг страницы 247, смещение: 24600, сортировка: _ASC
# Добавлено новых ID: 95, всего: 24581
# Парсинг страницы 248, смещение: 24700, сортировка: _ASC
# Добавлено новых ID: 98, всего: 24679
# Парсинг страницы 249, смещение: 24800, сортировка: _ASC
# Добавлено новых ID: 100, всего: 24779
# Парсинг страницы 250, смещение: 24900, сортировка: _ASC
# Добавлено новых ID: 94, всего: 24873
# Парсинг страницы 251, смещение: 25000, сортировка: _ASC
# Добавлено новых ID: 99, всего: 24972
# Парсинг страницы 252, смещение: 25100, сортировка: _ASC
# Добавлено новых ID: 99, всего: 25071
# Сохранено 25071 ID игр в файл steam_game_ids_25000.csv
#
# Итоговый результат: 25071 уникальных ID игр
